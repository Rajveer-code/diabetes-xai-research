# %%
# Code for 03_pima_processing.ipynb

import pandas as pd
import os

print("Processing PIMA data...")

# 1. Load the data
pima_path = '../data/01_raw/PIMA/diabetes.csv'
pima_df = pd.read_csv(pima_path)

# 2. Rename columns to match the harmonized conceptual names
pima_rename_dict = {
    'Pregnancies': 'Pregnancies',
    'Glucose': 'Fasting_Glucose',
    'BloodPressure': 'Diastolic_BP',
    'SkinThickness': 'Skin_Thickness',
    'Insulin': 'Insulin',
    'BMI': 'BMI',
    'DiabetesPedigreeFunction': 'Family_History_Diabetes',
    'Age': 'Age',
    'Outcome': 'Diabetes_Outcome'
}
pima_clean_df = pima_df.rename(columns=pima_rename_dict)

# 3. Save the processed file
output_path = '../data/03_processed/pima_final.csv'
pima_clean_df.to_csv(output_path, index=False)

print("\nPIMA data has been harmonized and saved.")
pima_clean_df.head()
# Out:
# Processing PIMA data...
#
# PIMA data has been harmonized and saved.
#    Pregnancies  Fasting_Glucose  Diastolic_BP  Skin_Thickness  Insulin   BMI  \
# 0            6              148            72              35        0  33.6
# 1            1               85            66              29        0  26.6
# 2            8              183            64               0        0  23.3
# 3            1               89            66              23       94  28.1
# 4            0              137            40              35      168  43.1
#
#    Family_History_Diabetes  Age  Diabetes_Outcome
# 0                    0.627   50                 1
# 1                    0.351   31                 0
# 2                    0.672   32                 1
# 3                    0.167   21                 0
# 4                    2.288   33                 1
